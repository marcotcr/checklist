# %%
import sys
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"



def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

# %%
class CacheQuery(object):
    def __init__(self, endpoint_url="https://query.wikidata.org/sparql"):
        self.endpoint_url = endpoint_url
        self.cache = {}
    def query(self, query):
        if query not in self.cache:
            user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
        # TODO adjust user agent; see https://w.wiki/CX6
            sparql = SPARQLWrapper(self.endpoint_url, agent=user_agent)
            sparql.setQuery(query)
            sparql.setReturnFormat(JSON)
            self.cache[query] = sparql.query().convert()
        return self.cache[query]

# %%
wiki = CacheQuery()

# %%
import munch
query = '''
SELECT DISTINCT ?country ?countryLabel ?population (GROUP_CONCAT(DISTINCT ?langCode;separator=", ") AS ?langCodes) 
WHERE
{
  # ?country wdt:P31 wd:Q3624078;
           wdt:P1082 ?population.
  OPTIONAL {
  # ?country wdt:P37 ?lang .
  # ?lang wdt:P424 ?langCode .
    }
#   BIND("pt" as ?desiredLang).
#   FILTER(STRSTARTS(?langCode, ?desiredLang)).
#   ?lang wdt:P31/wdt:P279* wd:Q1860 .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
GROUP BY ?country ?countryLabel ?population
ORDER BY DESC(?population)
'''

results = wiki.query(query)

countries = []
for x in results['results']['bindings']:
    a = munch.Munch()
    a.code = x['country']['value'].split('/')[-1]
    a.label = munch.Munch()
    a.label.en = x['countryLabel']['value']
    a.lang_codes = x['langCodes']['value']
    a.primary_lang = x['langCodes']['value'].split(',')[0].split('-')[0]
    a.population = x['population']['value']
    countries.append(a)
countries[0].primary_lang='zh'

# %%
# countries[0].label
countries[0].label.en = 'China'
countries[2].label.en = 'United States'
countries[15].label.en = 'Congo'
countries[65].label.en = 'the Netherlands'
countries[113].label.en = 'Denmark'
countries[117].label.en = 'Congo'

# %%
roberta_languages = ['fr', 'en', 'de', 'af', 'sq', 'am', 'ar', 'hy', 'az', 'eu', 'be', 'bn', 'bs', 'br', 'bg', 'my', 'ca', 'zh', 'hr', 'cs', 'da', 'nl', 'eo', 'et', 'fi', 'gl', 'ka', 'el', 'gu', 'ha', 'he', 'hi', 'hu', 'is', 'id', 'ga', 'it', 'ja', 'jv', 'kn', 'kk', 'km', 'ko', 'ku', 'ky', 'lo', 'la', 'lv', 'lt', 'mk', 'mg', 'ms', 'ml', 'mr', 'mn', 'ne', 'no', 'ps', 'fa', 'pl', 'pt', 'pa', 'ro', 'ru', 'gd', 'sr', 'sd', 'si', 'sk', 'sl', 'so', 'es', 'su', 'sw', 'sv', 'ta', 'te', 'th', 'tr', 'uk', 'ur', 'ug', 'uz', 'vi', 'cy', 'xh', 'yi']
def extract_roberta(input_dict, verbose=False):
    ret = {}
    for x in roberta_languages:
        if x in input_dict:
            if x == 'zh':
                ret['zh'] = input_dict.get('zh-cn', input_dict.get('zh'))
            else:
                ret[x] = input_dict[x]
        if x not in input_dict:
            keys = [a for a in input_dict.keys() if a.startswith(x)]
            if keys:
                ret[x] = input_dict[keys[0]]
            else:
                pass
                if verbose:
                    print(x)
    return ret

# %%
print(roberta_languages)
# Out:
# ['fr', 'en', 'de', 'af', 'sq', 'am', 'ar', 'hy', 'az', 'eu', 'be', 'bn', 'bs', 'br', 'bg', 'my', 'ca', 'zh', 'hr', 'cs', 'da', 'nl', 'eo', 'et', 'fi', 'gl', 'ka', 'el', 'gu', 'ha', 'he', 'hi', 'hu', 'is', 'id', 'ga', 'it', 'ja', 'jv', 'kn', 'kk', 'km', 'ko', 'ku', 'ky', 'lo', 'la', 'lv', 'lt', 'mk', 'mg', 'ms', 'ml', 'mr', 'mn', 'ne', 'no', 'ps', 'fa', 'pl', 'pt', 'pa', 'ro', 'ru', 'gd', 'sr', 'sd', 'si', 'sk', 'sl', 'so', 'es', 'su', 'sw', 'sv', 'ta', 'te', 'th', 'tr', 'uk', 'ur', 'ug', 'uz', 'vi', 'cy', 'xh', 'yi']

# %%
query = '''
SELECT DISTINCT ?country ?countryLabel ?lang 
{
  # ?country rdfs:label ?countryLabel .
  FILTER(?country in (wd:%s)).
  BIND(lang(?countryLabel) as ?lang)
}
'''
for country in countries:
    print(country.label.en)
    results = wiki.query(query % country.code)
    langval = {}
    for x in results["results"]["bindings"]:
#         print(x)
        lang = x['lang']['value']
        val = x['countryLabel']['value']
        langval[lang]= val
    roberta_labels = extract_roberta(langval)
    for x, v in roberta_labels.items():
        country.label[x] = v
# Out:
# People's Republic of China
# India
# United States of America
# Indonesia
# Brazil
# Pakistan
# Nigeria
# Bangladesh
# Russia
# Mexico
# Japan
# Ethiopia
# Philippines
# Egypt
# Vietnam
# Democratic Republic of the Congo
# Germany
# Turkey
# Iran
# France
# United Kingdom
# Thailand
# Italy
# South Africa
# Tanzania
# Myanmar
# South Korea
# Colombia
# Kenya
# Spain
# Argentina
# Uganda
# Ukraine
# Algeria
# Sudan
# Poland
# Iraq
# Canada
# Morocco
# Afghanistan
# Saudi Arabia
# Uzbekistan
# Malaysia
# Angola
# Mozambique
# Nepal
# Peru
# Venezuela
# Yemen
# Ghana
# Madagascar
# North Korea
# Australia
# Ivory Coast
# Cameroon
# Niger
# Sri Lanka
# Romania
# Burkina Faso
# Malawi
# Mali
# Kazakhstan
# Syria
# Chile
# Guatemala
# Kingdom of the Netherlands
# Zambia
# Ecuador
# Zimbabwe
# Cambodia
# Senegal
# Chad
# Guinea
# South Sudan
# Rwanda
# Tunisia
# Cuba
# Belgium
# Benin
# Bolivia
# Somalia
# Haiti
# Burundi
# Greece
# Czech Republic
# Portugal
# Jordan
# Dominican Republic
# Sweden
# Azerbaijan
# Hungary
# Belarus
# United Arab Emirates
# Honduras
# Israel
# Tajikistan
# Austria
# Switzerland
# Papua New Guinea
# Togo
# Sierra Leone
# Serbia
# Bulgaria
# Laos
# Paraguay
# Libya
# El Salvador
# Nicaragua
# Kyrgyzstan
# Lebanon
# Singapore
# Turkmenistan
# Denmark
# Kingdom of Denmark
# Finland
# Slovakia
# Norway
# Republic of the Congo
# New Zealand
# Costa Rica
# Oman
# Ireland
# Liberia
# Central African Republic
# Kuwait
# Mauritania
# Croatia
# Panama
# Georgia
# Bosnia and Herzegovina
# Eritrea
# Uruguay
# Mongolia
# Albania
# Armenia
# Jamaica
# Lithuania
# Qatar
# Moldova
# Namibia
# Botswana
# Lesotho
# The Gambia
# North Macedonia
# Slovenia
# Gabon
# Latvia
# Guinea-Bissau
# Bahrain
# Trinidad and Tobago
# Eswatini
# Estonia
# East Timor
# Equatorial Guinea
# Mauritius
# Cyprus
# Djibouti
# Fiji
# Comoros
# Bhutan
# Guyana
# Luxembourg
# Montenegro
# Solomon Islands
# Suriname
# Cape Verde
# Malta
# Maldives
# Brunei
# The Bahamas
# Belize
# Iceland
# Barbados
# Vanuatu
# Orange Free State
# São Tomé and Príncipe
# Samoa
# Saint Lucia
# Kiribati
# Saint Vincent and the Grenadines
# Tonga
# Grenada
# Federated States of Micronesia
# Antigua and Barbuda
# Orange Free State
# Seychelles
# Andorra
# Dominica
# Saint Kitts and Nevis
# Marshall Islands
# Monaco
# Liechtenstein
# San Marino
# Palau
# Nauru
# Tuvalu
# Vatican City

# %%
query = '''
SELECT DISTINCT ?city ?cityLabel ?population
{
  # ?city wdt:P31/wdt:P279* wd:Q515 .
  # ?city wdt:P1082 ?population .
  # ?city wdt:P17 ?country .
  # ?city rdfs:label ?cityLabel .
  FILTER(lang(?cityLabel)="en").
  FILTER(?country in (wd:%s)).
}
ORDER BY DESC(?population) LIMIT 100
'''
for country in countries:
    country.cities = []
    results = wiki.query(query % country.code)
    print(country.label.en)
    for x in results["results"]["bindings"]:
        a = munch.Munch()
        a.code = x['city']['value'].split('/')[-1]
        a.label = munch.Munch()
        a.label.en = x['cityLabel']['value']
        a.population = x['population']['value']
        country.cities.append(a)
# Out:
# China
# India
# United States
# Indonesia
# Brazil
# Pakistan
# Nigeria
# Bangladesh
# Russia
# Mexico
# Japan
# Ethiopia
# Philippines
# Egypt
# Vietnam
# Congo
# Germany
# Turkey
# Iran
# France
# United Kingdom
# Thailand
# Italy
# South Africa
# Tanzania
# Myanmar
# South Korea
# Colombia
# Kenya
# Spain
# Argentina
# Uganda
# Ukraine
# Algeria
# Sudan
# Poland
# Iraq
# Canada
# Morocco
# Afghanistan
# Saudi Arabia
# Uzbekistan
# Malaysia
# Angola
# Mozambique
# Nepal
# Peru
# Venezuela
# Yemen
# Ghana
# Madagascar
# North Korea
# Australia
# Ivory Coast
# Cameroon
# Niger
# Sri Lanka
# Romania
# Burkina Faso
# Malawi
# Mali
# Kazakhstan
# Syria
# Chile
# Guatemala
# the Netherlands
# Zambia
# Ecuador
# Zimbabwe
# Cambodia
# Senegal
# Chad
# Guinea
# South Sudan
# Rwanda
# Tunisia
# Cuba
# Belgium
# Benin
# Bolivia
# Somalia
# Haiti
# Burundi
# Greece
# Czech Republic
# Portugal
# Jordan
# Dominican Republic
# Sweden
# Azerbaijan
# Hungary
# Belarus
# United Arab Emirates
# Honduras
# Israel
# Tajikistan
# Austria
# Switzerland
# Papua New Guinea
# Togo
# Sierra Leone
# Serbia
# Bulgaria
# Laos
# Paraguay
# Libya
# El Salvador
# Nicaragua
# Kyrgyzstan
# Lebanon
# Singapore
# Turkmenistan
# Denmark
# Denmark
# Finland
# Slovakia
# Norway
# Congo
# New Zealand
# Costa Rica
# Oman
# Ireland
# Liberia
# Central African Republic
# Kuwait
# Mauritania
# Croatia
# Panama
# Georgia
# Bosnia and Herzegovina
# Eritrea
# Uruguay
# Mongolia
# Albania
# Armenia
# Jamaica
# Lithuania
# Qatar
# Moldova
# Namibia
# Botswana
# Lesotho
# The Gambia
# North Macedonia
# Slovenia
# Gabon
# Latvia
# Guinea-Bissau
# Bahrain
# Trinidad and Tobago
# Eswatini
# Estonia
# East Timor
# Equatorial Guinea
# Mauritius
# Cyprus
# Djibouti
# Fiji
# Comoros
# Bhutan
# Guyana
# Luxembourg
# Montenegro
# Solomon Islands
# Suriname
# Cape Verde
# Malta
# Maldives
# Brunei
# The Bahamas
# Belize
# Iceland
# Barbados
# Vanuatu
# Orange Free State
# São Tomé and Príncipe
# Samoa
# Saint Lucia
# Kiribati
# Saint Vincent and the Grenadines
# Tonga
# Grenada
# Federated States of Micronesia
# Antigua and Barbuda
# Orange Free State
# Seychelles
# Andorra
# Dominica
# Saint Kitts and Nevis
# Marshall Islands
# Monaco
# Liechtenstein
# San Marino
# Palau
# Nauru
# Tuvalu
# Vatican City

# %%
# countries[0].cities[0].label

# %%
query = '''
SELECT DISTINCT ?city ?cityLabel ?lang 
{
  # ?city rdfs:label ?cityLabel .
  FILTER(?city in (wd:%s)).
  BIND(lang(?cityLabel) as ?lang)
}
'''
for country in countries:
    print(country.label.en)
    for city in country.cities:
        results = wiki.query(query % city.code)
        langval = {}
        for x in results["results"]["bindings"]:
            lang = x['lang']['value']
            val = x['cityLabel']['value']
            langval[lang]= val
        roberta_labels = extract_roberta(langval)
        for x, v in roberta_labels.items():
            city.label[x] = v
#         for x in roberta_languages:
#             if x in langval:
#                 if x == 'zh':
#                     city.label['zh'] = langval.get('zh-cn', langval.get('zh'))
#                 city.label[x] = langval[x]
#             if x not in langval:
#                 keys = [a for a in langval.keys() if a.startswith(x)]
#                 if keys:
#                     city.label[keys[0]] = langval[keys[0]]
# Out:
# China
# India
# United States
# Indonesia
# Brazil
# Pakistan
# Nigeria
# Bangladesh
# Russia
# Mexico
# Japan
# Ethiopia
# Philippines
# Egypt
# Vietnam
# Congo
# Germany
# Turkey
# Iran
# France
# United Kingdom
# Thailand
# Italy
# South Africa
# Tanzania
# Myanmar
# South Korea
# Colombia
# Kenya
# Spain
# Argentina
# Uganda
# Ukraine
# Algeria
# Sudan
# Poland
# Iraq
# Canada
# Morocco
# Afghanistan
# Saudi Arabia
# Uzbekistan
# Malaysia
# Angola
# Mozambique
# Nepal
# Peru
# Venezuela
# Yemen
# Ghana
# Madagascar
# North Korea
# Australia
# Ivory Coast
# Cameroon
# Niger
# Sri Lanka
# Romania
# Burkina Faso
# Malawi
# Mali
# Kazakhstan
# Syria
# Chile
# Guatemala
# the Netherlands
# Zambia
# Ecuador
# Zimbabwe
# Cambodia
# Senegal
# Chad
# Guinea
# South Sudan
# Rwanda
# Tunisia
# Cuba
# Belgium
# Benin
# Bolivia
# Somalia
# Haiti
# Burundi
# Greece
# Czech Republic
# Portugal
# Jordan
# Dominican Republic
# Sweden
# Azerbaijan
# Hungary
# Belarus
# United Arab Emirates
# Honduras
# Israel
# Tajikistan
# Austria
# Switzerland
# Papua New Guinea
# Togo
# Sierra Leone
# Serbia
# Bulgaria
# Laos
# Paraguay
# Libya
# El Salvador
# Nicaragua
# Kyrgyzstan
# Lebanon
# Singapore
# Turkmenistan
# Denmark
# Denmark
# Finland
# Slovakia
# Norway
# Congo
# New Zealand
# Costa Rica
# Oman
# Ireland
# Liberia
# Central African Republic
# Kuwait
# Mauritania
# Croatia
# Panama
# Georgia
# Bosnia and Herzegovina
# Eritrea
# Uruguay
# Mongolia
# Albania
# Armenia
# Jamaica
# Lithuania
# Qatar
# Moldova
# Namibia
# Botswana
# Lesotho
# The Gambia
# North Macedonia
# Slovenia
# Gabon
# Latvia
# Guinea-Bissau
# Bahrain
# Trinidad and Tobago
# Eswatini
# Estonia
# East Timor
# Equatorial Guinea
# Mauritius
# Cyprus
# Djibouti
# Fiji
# Comoros
# Bhutan
# Guyana
# Luxembourg
# Montenegro
# Solomon Islands
# Suriname
# Cape Verde
# Malta
# Maldives
# Brunei
# The Bahamas
# Belize
# Iceland
# Barbados
# Vanuatu
# Orange Free State
# São Tomé and Príncipe
# Samoa
# Saint Lucia
# Kiribati
# Saint Vincent and the Grenadines
# Tonga
# Grenada
# Federated States of Micronesia
# Antigua and Barbuda
# Orange Free State
# Seychelles
# Andorra
# Dominica
# Saint Kitts and Nevis
# Marshall Islands
# Monaco
# Liechtenstein
# San Marino
# Palau
# Nauru
# Tuvalu
# Vatican City

# %% [markdown]
# nationalities

# %%
results
# Out:
# {'head': {'vars': ['nat', 'country']}, 'results': {'bindings': []}}

# %%
query = '''
SELECT DISTINCT ?nat ?country
{
  # ?country wdt:P1549 ?nat .
  FILTER(lang(?nat)="en").
  FILTER(?country in (%s)).
}'''

nationality = {}
for country in countries:
    print(country.label.en)
    nat = query % ('wd:%s' % country.code)
    results = wiki.query(nat)
    for x in results["results"]["bindings"]:
        country.nationality = x['nat']['value']
# Out:
# China
# India
# United States
# Indonesia
# Brazil
# Pakistan
# Nigeria
# Bangladesh
# Russia
# Mexico
# Japan
# Ethiopia
# Philippines
# Egypt
# Vietnam
# Congo
# Germany
# Turkey
# Iran
# France
# United Kingdom
# Thailand
# Italy
# South Africa
# Tanzania
# Myanmar
# South Korea
# Colombia
# Kenya
# Spain
# Argentina
# Uganda
# Ukraine
# Algeria
# Sudan
# Poland
# Iraq
# Canada
# Morocco
# Afghanistan
# Saudi Arabia
# Uzbekistan
# Malaysia
# Angola
# Mozambique
# Nepal
# Peru
# Venezuela
# Yemen
# Ghana
# Madagascar
# North Korea
# Australia
# Ivory Coast
# Cameroon
# Niger
# Sri Lanka
# Romania
# Burkina Faso
# Malawi
# Mali
# Kazakhstan
# Syria
# Chile
# Guatemala
# the Netherlands
# Zambia
# Ecuador
# Zimbabwe
# Cambodia
# Senegal
# Chad
# Guinea
# South Sudan
# Rwanda
# Tunisia
# Cuba
# Belgium
# Benin
# Bolivia
# Somalia
# Haiti
# Burundi
# Greece
# Czech Republic
# Portugal
# Jordan
# Dominican Republic
# Sweden
# Azerbaijan
# Hungary
# Belarus
# United Arab Emirates
# Honduras
# Israel
# Tajikistan
# Austria
# Switzerland
# Papua New Guinea
# Togo
# Sierra Leone
# Serbia
# Bulgaria
# Laos
# Paraguay
# Libya
# El Salvador
# Nicaragua
# Kyrgyzstan
# Lebanon
# Singapore
# Turkmenistan
# Denmark
# Denmark
# Finland
# Slovakia
# Norway
# Congo
# New Zealand
# Costa Rica
# Oman
# Ireland
# Liberia
# Central African Republic
# Kuwait
# Mauritania
# Croatia
# Panama
# Georgia
# Bosnia and Herzegovina
# Eritrea
# Uruguay
# Mongolia
# Albania
# Armenia
# Jamaica
# Lithuania
# Qatar
# Moldova
# Namibia
# Botswana
# Lesotho
# The Gambia
# North Macedonia
# Slovenia
# Gabon
# Latvia
# Guinea-Bissau
# Bahrain
# Trinidad and Tobago
# Eswatini
# Estonia
# East Timor
# Equatorial Guinea
# Mauritius
# Cyprus
# Djibouti
# Fiji
# Comoros
# Bhutan
# Guyana
# Luxembourg
# Montenegro
# Solomon Islands
# Suriname
# Cape Verde
# Malta
# Maldives
# Brunei
# The Bahamas
# Belize
# Iceland
# Barbados
# Vanuatu
# Orange Free State
# São Tomé and Príncipe
# Samoa
# Saint Lucia
# Kiribati
# Saint Vincent and the Grenadines
# Tonga
# Grenada
# Federated States of Micronesia
# Antigua and Barbuda
# Orange Free State
# Seychelles
# Andorra
# Dominica
# Saint Kitts and Nevis
# Marshall Islands
# Monaco
# Liechtenstein
# San Marino
# Palau
# Nauru
# Tuvalu
# Vatican City

# %%
[(i, x.label.en) for i, x in enumerate(countries) if 'nationality' not in x]
# Out:
# [(20, 'United Kingdom'),
#  (32, 'Ukraine'),
#  (39, 'Afghanistan'),
#  (40, 'Saudi Arabia'),
#  (174, 'Orange Free State'),
#  (184, 'Orange Free State')]

# %%
countries[20].nationality = 'English'
countries[32].nationality = 'Ukrainian'
countries[39].nationality = 'Afghan'
countries[40].nationality = 'Saudi'
countries[174].nationality = 'Orange'
countries[184].nationality = 'Orange'

# %%
[(i, x.label.en) for i, x in enumerate(countries) if  not in x]

# %%
[(x.label.en, x.nationality) for x in countries]
# Out:
# [('China', 'Chinese'),
#  ('India', 'Indian'),
#  ('United States', 'American'),
#  ('Indonesia', 'Indonesian'),
#  ('Brazil', 'Brazilian'),
#  ('Pakistan', 'Pakistani'),
#  ('Nigeria', 'Nigerian'),
#  ('Bangladesh', 'Bangladeshi'),
#  ('Russia', 'Russian'),
#  ('Mexico', 'Mexican'),
#  ('Japan', 'Japanese'),
#  ('Ethiopia', 'Ethiopian'),
#  ('Philippines', 'Filipino'),
#  ('Egypt', 'Egyptian'),
#  ('Vietnam', 'Vietnamese'),
#  ('Congo', 'Congolese'),
#  ('Germany', 'German'),
#  ('Turkey', 'Turkish'),
#  ('Iran', 'Persian'),
#  ('France', 'French'),
#  ('United Kingdom', 'English'),
#  ('Thailand', 'Thai'),
#  ('Italy', 'Italian'),
#  ('South Africa', 'South African'),
#  ('Tanzania', 'Tanzanian'),
#  ('Myanmar', 'Burmese'),
#  ('South Korea', 'South Korean'),
#  ('Colombia', 'Colombian'),
#  ('Kenya', 'Kenyan'),
#  ('Spain', 'Spanish'),
#  ('Argentina', 'Argentinian'),
#  ('Uganda', 'Ugandan'),
#  ('Ukraine', 'Ukrainian'),
#  ('Algeria', 'Algerian'),
#  ('Sudan', 'Sudanese'),
#  ('Poland', 'Polish'),
#  ('Iraq', 'Iraqi'),
#  ('Canada', 'Canadian'),
#  ('Morocco', 'Moroccan'),
#  ('Afghanistan', 'Afghan'),
#  ('Saudi Arabia', 'Saudi'),
#  ('Uzbekistan', 'Uzbek'),
#  ('Malaysia', 'Malaysian'),
#  ('Angola', 'Angolan'),
#  ('Mozambique', 'Mozambican'),
#  ('Nepal', 'Nepali'),
#  ('Peru', 'Peruvian'),
#  ('Venezuela', 'Venezuelan'),
#  ('Yemen', 'Yemeni'),
#  ('Ghana', 'Ghanaian'),
#  ('Madagascar', 'Malagasy'),
#  ('North Korea', 'North Korean'),
#  ('Australia', 'Australian'),
#  ('Ivory Coast', 'Ivorian'),
#  ('Cameroon', 'Cameroonian'),
#  ('Niger', 'Nigerien'),
#  ('Sri Lanka', 'Sri Lankan'),
#  ('Romania', 'Romanian'),
#  ('Burkina Faso', 'Burkinabe'),
#  ('Malawi', 'Malawian'),
#  ('Mali', 'Malian'),
#  ('Kazakhstan', 'Kazakhstani'),
#  ('Syria', 'Syrian'),
#  ('Chile', 'Chilean'),
#  ('Guatemala', 'Guatemalan'),
#  ('the Netherlands', 'Dutch'),
#  ('Zambia', 'Zambians'),
#  ('Ecuador', 'Ecuadorian'),
#  ('Zimbabwe', 'Zimbabwean'),
#  ('Cambodia', 'Cambodian'),
#  ('Senegal', 'Senegalese'),
#  ('Chad', 'Chadian'),
#  ('Guinea', 'Guinean'),
#  ('South Sudan', 'South Sudanese'),
#  ('Rwanda', 'Rwandese'),
#  ('Tunisia', 'Tunisian'),
#  ('Cuba', 'Cuban'),
#  ('Belgium', 'Belgian'),
#  ('Benin', 'Beninese'),
#  ('Bolivia', 'Bolivian'),
#  ('Somalia', 'Somalian'),
#  ('Haiti', 'Haitian'),
#  ('Burundi', 'Burundian'),
#  ('Greece', 'Greek'),
#  ('Czech Republic', 'Czech'),
#  ('Portugal', 'Portuguese'),
#  ('Jordan', 'Jordanian'),
#  ('Dominican Republic', 'Dominican'),
#  ('Sweden', 'Swedish'),
#  ('Azerbaijan', 'Azeri'),
#  ('Hungary', 'Hungarian'),
#  ('Belarus', 'Belarusian'),
#  ('United Arab Emirates', 'Emirian'),
#  ('Honduras', 'Honduran'),
#  ('Israel', 'Israelis'),
#  ('Tajikistan', 'Tajikistani'),
#  ('Austria', 'Austrian'),
#  ('Switzerland', 'Swiss'),
#  ('Papua New Guinea', 'Papua New Guinean'),
#  ('Togo', 'Togolese'),
#  ('Sierra Leone', 'Sierra Leonean'),
#  ('Serbia', 'Serbian'),
#  ('Bulgaria', 'Bulgarian'),
#  ('Laos', 'Laotian'),
#  ('Paraguay', 'Paraguayan'),
#  ('Libya', 'Libyan'),
#  ('El Salvador', 'Salvadoran'),
#  ('Nicaragua', 'Nicaraguan'),
#  ('Kyrgyzstan', 'Kyrgyzstani'),
#  ('Lebanon', 'Lebanese'),
#  ('Singapore', 'Singaporean'),
#  ('Turkmenistan', 'Turkmen'),
#  ('Denmark', 'Dane'),
#  ('Denmark', 'dane'),
#  ('Finland', 'Finn'),
#  ('Slovakia', 'Slovak'),
#  ('Norway', 'Norwegian'),
#  ('Congo', 'Congolese'),
#  ('New Zealand', 'New Zealand'),
#  ('Costa Rica', 'Costa Rican'),
#  ('Oman', 'Omani'),
#  ('Ireland', 'Irish'),
#  ('Liberia', 'Liberian'),
#  ('Central African Republic', 'Central African'),
#  ('Kuwait', 'Kuwaiti'),
#  ('Mauritania', 'Mauritanian'),
#  ('Croatia', 'Croatian'),
#  ('Panama', 'Panamanian'),
#  ('Georgia', 'Georgian'),
#  ('Bosnia and Herzegovina', 'Herzegovinian'),
#  ('Eritrea', 'Eritrean'),
#  ('Uruguay', 'Uruguayan'),
#  ('Mongolia', 'Mongol'),
#  ('Albania', 'Albanian'),
#  ('Armenia', 'Armenian'),
#  ('Jamaica', 'Jamaican'),
#  ('Lithuania', 'Lithuanian'),
#  ('Qatar', 'Qatari'),
#  ('Moldova', 'Moldovan'),
#  ('Namibia', 'Namibian'),
#  ('Botswana', 'Motswana'),
#  ('Lesotho', 'Mosotho'),
#  ('The Gambia', 'Gambian'),
#  ('North Macedonia', 'Macedonian'),
#  ('Slovenia', 'Slovenian'),
#  ('Gabon', 'Gabonese'),
#  ('Latvia', 'Latvian'),
#  ('Guinea-Bissau', 'Guinea-Bissauan'),
#  ('Bahrain', 'Bahraini'),
#  ('Trinidad and Tobago', 'Trinidadian'),
#  ('Eswatini', 'Swazi'),
#  ('Estonia', 'Estonian'),
#  ('East Timor', 'East Timorese'),
#  ('Equatorial Guinea', 'Equatorial Guinean'),
#  ('Mauritius', 'Mauritian'),
#  ('Cyprus', 'Cypriot'),
#  ('Djibouti', 'Djiboutian'),
#  ('Fiji', 'Fijian'),
#  ('Comoros', 'Comoran'),
#  ('Bhutan', 'Bhutanese'),
#  ('Guyana', 'Guyanese'),
#  ('Luxembourg', 'Luxembourgish'),
#  ('Montenegro', 'Montenegrin'),
#  ('Solomon Islands', 'Solomon Islands'),
#  ('Suriname', 'Surinamese'),
#  ('Cape Verde', 'Cape Verdean'),
#  ('Malta', 'Maltese'),
#  ('Maldives', 'Maldivian'),
#  ('Brunei', 'Bruneian'),
#  ('The Bahamas', 'Bahamian'),
#  ('Belize', 'Belizean'),
#  ('Iceland', 'Icelandic'),
#  ('Barbados', 'Barbadian'),
#  ('Vanuatu', 'Vanuatuan'),
#  ('Orange Free State', 'Orange'),
#  ('São Tomé and Príncipe', 'São Toméan'),
#  ('Samoa', 'Samoan'),
#  ('Saint Lucia', 'Saint Lucian'),
#  ('Kiribati', 'I-Kiribati'),
#  ('Saint Vincent and the Grenadines', 'Vincy'),
#  ('Tonga', 'Tongan'),
#  ('Grenada', 'Grenadian'),
#  ('Federated States of Micronesia', 'Micronesian'),
#  ('Antigua and Barbuda', 'Barbudan'),
#  ('Orange Free State', 'Orange'),
#  ('Seychelles', 'Seychelloise'),
#  ('Andorra', 'Andorran'),
#  ('Dominica', 'Dominican'),
#  ('Saint Kitts and Nevis', 'Nevisian'),
#  ('Marshall Islands', 'Marshallese'),
#  ('Monaco', 'Monegasque'),
#  ('Liechtenstein', 'Liechtensteiner'),
#  ('San Marino', 'Sammarinese'),
#  ('Palau', 'Palauan'),
#  ('Nauru', 'Nauruan'),
#  ('Tuvalu', 'Tuvaluan'),
#  ('Vatican City', 'Vatican')]

# %%
countries[20]
# Out:
# Munch({'code': 'Q145', 'label': Munch({'en': 'United Kingdom', 'fr': 'Royaume-Uni', 'de': 'Vereinigtes Königreich', 'af': 'Verenigde Koninkryk', 'sq': 'Britania e Madhe', 'am': 'ዩናይትድ ኪንግደም', 'ar': 'المملكة المتحدة', 'hy': 'Միացյալ Թագավորություն', 'az': 'Böyük Britaniya', 'eu': 'Erresuma Batua', 'be': 'Вялікабрытанія', 'bn': 'যুক্তরাজ্য', 'bs': 'Ujedinjeno Kraljevstvo', 'br': 'Rouantelezh-Unanet', 'bg': 'Великобритания', 'my': 'ယူနိုက်တက် ကင်းဒမ်း', 'ca': 'Regne Unit', 'zh': '英国', 'hr': 'Ujedinjeno Kraljevstvo', 'cs': 'Spojené království', 'da': 'Storbritannien', 'nl': 'Verenigd Koninkrijk', 'eo': 'Unuiĝinta Reĝlando', 'et': 'Suurbritannia', 'fi': 'Yhdistynyt kuningaskunta', 'gl': 'Reino Unido', 'ka': 'გაერთიანებული სამეფო', 'el': 'Ηνωμένο Βασίλειο', 'gu': 'યુનાઇટેડ કિંગડમ', 'ha': 'Birtaniya', 'he': 'הממלכה המאוחדת', 'hi': 'यूनाइटेड किंगडम', 'hu': 'Egyesült Királyság', 'is': 'Bretland', 'id': 'Britania Raya', 'ga': 'An Ríocht Aontaithe', 'it': 'Regno Unito', 'ja': 'イギリス', 'jv': 'Britania Raya', 'kn': 'ಯುನೈಟೆಡ್ ಕಿಂಗ್ ಡಂ', 'kk': 'Ұлыбритания', 'km': 'សហរាជាណាចក្រ', 'ko': '영국', 'ku': 'Keyaniya Yekbûyî', 'ky': 'Улуу Британия жана Түндүк Ирландия', 'lo': 'ສະຫະລາຊະອານາຈັກ', 'la': 'Britanniarum Regnum', 'lv': 'Apvienotā Karaliste', 'lt': 'Jungtinė Karalystė', 'mk': 'Обединето Кралство', 'mg': 'Fanjakana Mitambatra', 'ms': 'United Kingdom', 'ml': 'യുണൈറ്റഡ് കിങ്ഡം', 'mr': 'युनायटेड किंग्डम', 'mn': 'Нэгдсэн Вант Улс', 'ne': 'संयुक्त अधिराज्य', 'no': 'Storbritannia', 'ps': 'بريتانيا', 'fa': 'بریتانیا', 'pl': 'Wielka Brytania', 'pt': 'Reino Unido', 'pa': 'ਯੂਨਾਈਟਡ ਕਿੰਗਡਮ', 'ro': 'Regatul Unit', 'ru': 'Великобритания', 'gd': 'an Rìoghachd Aonaichte', 'sr': 'Уједињено Краљевство', 'sd': 'گڏيل بادشاھت', 'si': 'එක්සත් රාජධානිය', 'sk': 'Spojené kráľovstvo', 'sl': 'Združeno kraljestvo', 'so': 'Midowga boqortooyada Britan', 'es': 'Reino Unido', 'su': 'Britania', 'sw': 'Ufalme wa Muungano', 'sv': 'Storbritannien', 'ta': 'ஐக்கிய இராச்சியம்', 'te': 'యునైటెడ్ కింగ్డమ్', 'th': 'สหราชอาณาจักร', 'tr': 'Birleşik Krallık', 'uk': 'Велика Британія', 'ur': 'مملکت متحدہ', 'ug': 'بۈيۈك بېرىتانىيە', 'uz': 'Birlashgan Qirollik', 'vi': 'Vương quốc Liên hiệp Anh và Bắc Ireland', 'cy': 'y Deyrnas Unedig', 'yi': 'פאראייניגטע קעניגרייך'}), 'lang_codes': 'en', 'primary_lang': 'en', 'population': '66022273', 'cities': [Munch({'code': 'Q84', 'label': Munch({'en': 'London', 'fr': 'Londres', 'de': 'London', 'af': 'Londen', 'sq': 'Londër', 'am': 'ለንደን', 'ar': 'لندن', 'hy': 'Լոնդոն', 'az': 'London', 'eu': 'Londres', 'be': 'Лондан', 'bn': 'লন্ডন', 'bs': 'London', 'br': 'Londrez', 'bg': 'Лондон', 'my': 'လန်ဒန်မြို့', 'ca': 'Londres', 'zh': '伦敦', 'hr': 'London', 'cs': 'Londýn', 'da': 'London', 'nl': 'Londen', 'eo': 'Londono', 'et': 'London', 'fi': 'Lontoo', 'gl': 'Londres', 'ka': 'ლონდონი', 'el': 'Λονδίνο', 'gu': 'લંડન', 'ha': 'Landan', 'he': 'לונדון', 'hi': 'लंदन', 'hu': 'London', 'is': 'London', 'id': 'London', 'ga': 'Londain', 'it': 'Londra', 'ja': 'ロンドン', 'jv': 'London', 'kn': 'ಲಂಡನ್', 'kk': 'Лондон', 'km': 'ទីក្រុងឡុង', 'ko': '런던', 'ku': 'London', 'ky': 'Лондон', 'lo': 'ລອນດອນ', 'la': 'Londinium', 'lv': 'Londona', 'lt': 'Londonas', 'mk': 'Лондон', 'mg': 'London', 'ms': 'London', 'ml': 'ലണ്ടൻ', 'mr': 'लंडन', 'mn': 'Лондон', 'ne': 'लण्डन', 'no': 'London', 'ps': 'لندن', 'fa': 'لندن', 'pl': 'Londyn', 'pt': 'Londres', 'pa': 'ਲੰਡਨ', 'ro': 'Londra', 'ru': 'Лондон', 'gd': 'Lunnainn', 'sr': 'Лондон', 'sd': 'لنڊن', 'si': 'ලන්ඩන්', 'sk': 'Londýn', 'sl': 'London', 'so': 'London', 'es': 'Londres', 'su': 'London', 'sw': 'London', 'sv': 'London', 'ta': 'இலண்டன்', 'te': 'లండన్', 'th': 'ลอนดอน', 'tr': 'Londra', 'uk': 'Лондон', 'ur': 'لندن', 'ug': 'London', 'uz': 'London', 'vi': 'Luân Đôn', 'cy': 'Llundain', 'yi': 'לאנדאן'}), 'population': '8908081'}), Munch({'code': 'Q39121', 'label': Munch({'en': 'Leeds', 'fr': 'Leeds', 'de': 'Leeds', 'af': 'Leeds', 'am': 'ሊድስ', 'ar': 'ليدز', 'hy': 'Լիդս', 'az': 'Lids', 'eu': 'Leeds', 'be': 'Лідс', 'bn': 'লীড্স', 'bs': 'Leeds', 'br': 'Leeds', 'bg': 'Ли ...

# %%
countries[20].nationality
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.virtualenvs/checklist/lib/python3.6/site-packages/munch/__init__.py in __getattr__(self, k)
#     102             # Throws exception if not in prototype chain
# --> 103             return object.__getattribute__(self, k)
#     104         except AttributeError:
#
# AttributeError: 'Munch' object has no attribute 'nationality'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/.virtualenvs/checklist/lib/python3.6/site-packages/munch/__init__.py in __getattr__(self, k)
#     105             try:
# --> 106                 return self[k]
#     107             except KeyError:
#
# KeyError: 'nationality'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-a7198c9d67ac> in <module>
# ----> 1 countries[20].nationality
#
# ~/.virtualenvs/checklist/lib/python3.6/site-packages/munch/__init__.py in __getattr__(self, k)
#     106                 return self[k]
#     107             except KeyError:
# --> 108                 raise AttributeError(k)
#     109
#     110     def __setattr__(self, k, v):
#
# AttributeError: nationality

# %%
import pickle

# %%
pickle.dump(countries, open('/home/marcotcr/tmp/country_stuff.pkl', 'wb'))

# %% [markdown]
# First names

# %%
query = '''
SELECT ?name ?nameLabel ?count
WITH {
  SELECT ?name ?nameLabel (count(?person) AS ?count) WHERE {
    # ?person wdt:P735 ?name .  
    # ?person wdt:P27 %s . 
    # ?person wdt:P21 %s .
  }
  GROUP BY ?name ?nameLabel
  ORDER BY DESC(?count)
  LIMIT 100
} AS %%results
WHERE {
  INCLUDE %%results
  SERVICE wikibase:label { bd:serviceParam wikibase:language "%s,en". }
}
ORDER BY DESC(?count)
'''
import collections
male_names = collections.defaultdict(lambda: collections.defaultdict(lambda: 0))
female_names = collections.defaultdict(lambda: collections.defaultdict(lambda: 0))
male_by_country = collections.defaultdict(lambda: collections.defaultdict(lambda: 0))
female_by_country= collections.defaultdict(lambda: collections.defaultdict(lambda: 0))
for country in countries:
    print(country.label.en)
    print(country.primary_lang)
    male = query % ('wd:%s' % country.code, 'wd:Q6581097', country.primary_lang)
    results = wiki.query(male)
    for x in results["results"]["bindings"]:
#         print(x)
        male_names[country.primary_lang][x['nameLabel']['value']] += int(x['count']['value'])
        male_by_country[country.label.en.replace(' ', '_')][x['nameLabel']['value']] += int(x['count']['value'])
    female = query % ('wd:%s' % country.code, 'wd:Q6581072', country.primary_lang)
    results = wiki.query(female)
    for x in results["results"]["bindings"]:
        female_names[country.primary_lang][x['nameLabel']['value']] += int(x['count']['value'])
        female_by_country[country.label.en.replace(' ', '_')][x['nameLabel']['value']] += int(x['count']['value'])
# Out:
# China
# zh
# India
# hi
# United States
# en
# Indonesia
# id
# Brazil
# pt
# Pakistan
# ur
# Nigeria
# en
# Bangladesh
# bn
# Russia
# ru
# Mexico
# es
# Japan
# ja
# Ethiopia
# am
# Philippines
# en
# Egypt
# ar
# Vietnam
# vi
# Congo
# fr
# Germany
# de
# Turkey
# tr
# Iran
# fa
# France
# fr
# United Kingdom
# en
# Thailand
# th
# Italy
# it
# South Africa
# en
# Tanzania
# en
# Myanmar
# my
# South Korea
# ko
# Colombia
# es
# Kenya
# en
# Spain
# es
# Argentina
# es
# Uganda
# en
# Ukraine
# uk
# Algeria
# ar
# Sudan
# en
# Poland
# pl
# Iraq
# ar
# Canada
# fr
# Morocco
# ar
# Afghanistan
# uz
# Saudi Arabia
# ar
# Uzbekistan
# uz
# Malaysia
# ms
# Angola
# pt
# Mozambique
# pt
# Nepal
# ne
# Peru
# es
# Venezuela
# es
# Yemen
# ar
# Ghana
# en
# Madagascar
# fr
# North Korea
# ko
# Australia
# en
# Ivory Coast
# fr
# Cameroon
# fr
# Niger
# fr
# Sri Lanka
# ta
# Romania
# ro
# Burkina Faso
# fr
# Malawi
# en
# Mali
# fr
# Kazakhstan
# ru
# Syria
# ar
# Chile
# es
# Guatemala
# es
# the Netherlands
# nl
# Zambia
# en
# Ecuador
# es
# Zimbabwe
# en
# Cambodia
# km
# Senegal
# fr
# Chad
# fr
# Guinea
# fr
# South Sudan
# en
# Rwanda
# fr
# Tunisia
# ar
# Cuba
# es
# Belgium
# fr
# Benin
# fr
# Bolivia
# es
# Somalia
# so
# Haiti
# fr
# Burundi
# fr
# Greece
# el
# Czech Republic
# cs
# Portugal
# pt
# Jordan
# ar
# Dominican Republic
# es
# Sweden
# sv
# Azerbaijan
# az
# Hungary
# hu
# Belarus
# ru
# United Arab Emirates
# ar
# Honduras
# es
# Israel
# he
# Tajikistan
# ru
# Austria
# de
# Switzerland
# fr
# Papua New Guinea
# en
# Togo
# fr
# Sierra Leone
# en
# Serbia
# sr
# Bulgaria
# bg
# Laos
# lo
# Paraguay
# es
# Libya
# ar
# El Salvador
# es
# Nicaragua
# es
# Kyrgyzstan
# ru
# Lebanon
# ar
# Singapore
# en
# Turkmenistan
# tk
# Denmark
# da
# Denmark
# da
# Finland
# fi
# Slovakia
# sk
# Norway
# no
# Congo
# fr
# New Zealand
# en
# Costa Rica
# es
# Oman
# ar
# Ireland
# en
# Liberia
# en
# Central African Republic
# fr
# Kuwait
# ar
# Mauritania
# fr
# Croatia
# hr
# Panama
# es
# Georgia
# ab
# Bosnia and Herzegovina
# hr
# Eritrea
# en
# Uruguay
# es
# Mongolia
# mn
# Albania
# sq
# Armenia
# hy
# Jamaica
# en
# Lithuania
# lt
# Qatar
# ar
# Moldova
# ro
# Namibia
# en
# Botswana
# en
# Lesotho
# en
# The Gambia
# en
# North Macedonia
# sq
# Slovenia
# sl
# Gabon
# fr
# Latvia
# lv
# Guinea-Bissau
# pt
# Bahrain
# ar
# Trinidad and Tobago
# en
# Eswatini
# en
# Estonia
# et
# East Timor
# pt
# Equatorial Guinea
# fr
# Mauritius
# fr
# Cyprus
# tr
# Djibouti
# ar
# Fiji
# en
# Comoros
# fr
# Bhutan
# dz
# Guyana
# en
# Luxembourg
# fr
# Montenegro
# cnr
# Solomon Islands
# en
# Suriname
# nl
# Cape Verde
# pt
# Malta
# en
# Maldives
# dv
# Brunei
# en
# The Bahamas
# en
# Belize
# en
# Iceland
# is
# Barbados
# en
# Vanuatu
# fr
# Orange Free State
# nl
# São Tomé and Príncipe
# pt
# Samoa
# en
# Saint Lucia
# en
# Kiribati
# en
# Saint Vincent and the Grenadines
# en
# Tonga
# en
# Grenada
# en
# Federated States of Micronesia
# en
# Antigua and Barbuda
# en
# Orange Free State
# nl
# Seychelles
# fr
# Andorra
# ca
# Dominica
# en
# Saint Kitts and Nevis
# en
# Marshall Islands
# en
# Monaco
# fr
# Liechtenstein
# de
# San Marino
# it
# Palau
# en
# Nauru
# en
# Tuvalu
# en
# Vatican City
# fr

# %% [markdown]
# First names in english

# %%
query = '''
SELECT ?name ?nameLabel ?count
WITH {
  SELECT ?name ?nameLabel (count(?person) AS ?count) WHERE {
    # ?person wdt:P735 ?name .  
    # ?person wdt:P27 %s . 
    # ?person wdt:P21 %s .
  }
  GROUP BY ?name ?nameLabel
  ORDER BY DESC(?count)
  LIMIT 100
} AS %%results
WHERE {
  INCLUDE %%results
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
ORDER BY DESC(?count)
'''
import collections
male_by_country_e = collections.defaultdict(lambda: collections.defaultdict(lambda: 0))
female_by_country_e= collections.defaultdict(lambda: collections.defaultdict(lambda: 0))
for country in countries:
    print(country.label.en)
    male = query % ('wd:%s' % country.code, 'wd:Q6581097')
    results = wiki.query(male)
    for x in results["results"]["bindings"]:
#         print(x)
        male_by_country_e[country.label.en.replace(' ', '_')][x['nameLabel']['value']] += int(x['count']['value'])
    female = query % ('wd:%s' % country.code, 'wd:Q6581072')
    results = wiki.query(female)
    for x in results["results"]["bindings"]:
        female_by_country_e[country.label.en.replace(' ', '_')][x['nameLabel']['value']] += int(x['count']['value'])
# Out:
# China
# India
# United States
# Indonesia
# Brazil
# Pakistan
# Nigeria
# Bangladesh
# Russia
# Mexico
# Japan
# Ethiopia
# Philippines
# Egypt
# Vietnam
# Congo
# Germany
# Turkey
# Iran
# France
# United Kingdom
# Thailand
# Italy
# South Africa
# Tanzania
# Myanmar
# South Korea
# Colombia
# Kenya
# Spain
# Argentina
# Uganda
# Ukraine
# Algeria
# Sudan
# Poland
# Iraq
# Canada
# Morocco
# Afghanistan
# Saudi Arabia
# Uzbekistan
# Malaysia
# Angola
# Mozambique
# Nepal
# Peru
# Venezuela
# Yemen
# Ghana
# Madagascar
# North Korea
# Australia
# Ivory Coast
# Cameroon
# Niger
# Sri Lanka
# Romania
# Burkina Faso
# Malawi
# Mali
# Kazakhstan
# Syria
# Chile
# Guatemala
# the Netherlands
# Zambia
# Ecuador
# Zimbabwe
# Cambodia
# Senegal
# Chad
# Guinea
# South Sudan
# Rwanda
# Tunisia
# Cuba
# Belgium
# Benin
# Bolivia
# Somalia
# Haiti
# Burundi
# Greece
# Czech Republic
# Portugal
# Jordan
# Dominican Republic
# Sweden
# Azerbaijan
# Hungary
# Belarus
# United Arab Emirates
# Honduras
# Israel
# Tajikistan
# Austria
# Switzerland
# Papua New Guinea
# Togo
# Sierra Leone
# Serbia
# Bulgaria
# Laos
# Paraguay
# Libya
# El Salvador
# Nicaragua
# Kyrgyzstan
# Lebanon
# Singapore
# Turkmenistan
# Denmark
# Denmark
# Finland
# Slovakia
# Norway
# Congo
# New Zealand
# Costa Rica
# Oman
# Ireland
# Liberia
# Central African Republic
# Kuwait
# Mauritania
# Croatia
# Panama
# Georgia
# Bosnia and Herzegovina
# Eritrea
# Uruguay
# Mongolia
# Albania
# Armenia
# Jamaica
# Lithuania
# Qatar
# Moldova
# Namibia
# Botswana
# Lesotho
# The Gambia
# North Macedonia
# Slovenia
# Gabon
# Latvia
# Guinea-Bissau
# Bahrain
# Trinidad and Tobago
# Eswatini
# Estonia
# East Timor
# Equatorial Guinea
# Mauritius
# Cyprus
# Djibouti
# Fiji
# Comoros
# Bhutan
# Guyana
# Luxembourg
# Montenegro
# Solomon Islands
# Suriname
# Cape Verde
# Malta
# Maldives
# Brunei
# The Bahamas
# Belize
# Iceland
# Barbados
# Vanuatu
# Orange Free State
# São Tomé and Príncipe
# Samoa
# Saint Lucia
# Kiribati
# Saint Vincent and the Grenadines
# Tonga
# Grenada
# Federated States of Micronesia
# Antigua and Barbuda
# Orange Free State
# Seychelles
# Andorra
# Dominica
# Saint Kitts and Nevis
# Marshall Islands
# Monaco
# Liechtenstein
# San Marino
# Palau
# Nauru
# Tuvalu
# Vatican City

# %% [markdown]
# Last names

# %%
query = '''
SELECT ?name ?nameLabel ?count
WITH {
  SELECT ?name ?nameLabel (count(?person) AS ?count) WHERE {
    # ?person wdt:P734 ?name .  
    # ?person wdt:P27 %s . 
  }
  GROUP BY ?name ?nameLabel
  ORDER BY DESC(?count)
  LIMIT 100
} AS %%results
WHERE {
  INCLUDE %%results
  SERVICE wikibase:label { bd:serviceParam wikibase:language "%s,en". }
}
ORDER BY DESC(?count)
'''
last_names = collections.defaultdict(lambda: collections.defaultdict(lambda: 0))
last_by_country = collections.defaultdict(lambda: collections.defaultdict(lambda: 0))
for country in countries:
    print(country.label.en)
    print(country.primary_lang)
    last = query % ('wd:%s' % country.code, country.primary_lang)
    results = wiki.query(last)
    for x in results["results"]["bindings"]:
#         print(x)
        last_names[country.primary_lang][x['nameLabel']['value']] += int(x['count']['value'])
        last_by_country[country.label.en.replace(' ', '_')][x['nameLabel']['value']] += int(x['count']['value'])
# Out:
# China
# zh
# India
# hi
# United States
# en
# Indonesia
# id
# Brazil
# pt
# Pakistan
# ur
# Nigeria
# en
# Bangladesh
# bn
# Russia
# ru
# Mexico
# es
# Japan
# ja
# Ethiopia
# am
# Philippines
# en
# Egypt
# ar
# Vietnam
# vi
# Congo
# fr
# Germany
# de
# Turkey
# tr
# Iran
# fa
# France
# fr
# United Kingdom
# en
# Thailand
# th
# Italy
# it
# South Africa
# en
# Tanzania
# en
# Myanmar
# my
# South Korea
# ko
# Colombia
# es
# Kenya
# en
# Spain
# es
# Argentina
# es
# Uganda
# en
# Ukraine
# uk
# Algeria
# ar
# Sudan
# en
# Poland
# pl
# Iraq
# ar
# Canada
# fr
# Morocco
# ar
# Afghanistan
# uz
# Saudi Arabia
# ar
# Uzbekistan
# uz
# Malaysia
# ms
# Angola
# pt
# Mozambique
# pt
# Nepal
# ne
# Peru
# es
# Venezuela
# es
# Yemen
# ar
# Ghana
# en
# Madagascar
# fr
# North Korea
# ko
# Australia
# en
# Ivory Coast
# fr
# Cameroon
# fr
# Niger
# fr
# Sri Lanka
# ta
# Romania
# ro
# Burkina Faso
# fr
# Malawi
# en
# Mali
# fr
# Kazakhstan
# ru
# Syria
# ar
# Chile
# es
# Guatemala
# es
# the Netherlands
# nl
# Zambia
# en
# Ecuador
# es
# Zimbabwe
# en
# Cambodia
# km
# Senegal
# fr
# Chad
# fr
# Guinea
# fr
# South Sudan
# en
# Rwanda
# fr
# Tunisia
# ar
# Cuba
# es
# Belgium
# fr
# Benin
# fr
# Bolivia
# es
# Somalia
# so
# Haiti
# fr
# Burundi
# fr
# Greece
# el
# Czech Republic
# cs
# Portugal
# pt
# Jordan
# ar
# Dominican Republic
# es
# Sweden
# sv
# Azerbaijan
# az
# Hungary
# hu
# Belarus
# ru
# United Arab Emirates
# ar
# Honduras
# es
# Israel
# he
# Tajikistan
# ru
# Austria
# de
# Switzerland
# fr
# Papua New Guinea
# en
# Togo
# fr
# Sierra Leone
# en
# Serbia
# sr
# Bulgaria
# bg
# Laos
# lo
# Paraguay
# es
# Libya
# ar
# El Salvador
# es
# Nicaragua
# es
# Kyrgyzstan
# ru
# Lebanon
# ar
# Singapore
# en
# Turkmenistan
# tk
# Denmark
# da
# Denmark
# da
# Finland
# fi
# Slovakia
# sk
# Norway
# no
# Congo
# fr
# New Zealand
# en
# Costa Rica
# es
# Oman
# ar
# Ireland
# en
# Liberia
# en
# Central African Republic
# fr
# Kuwait
# ar
# Mauritania
# fr
# Croatia
# hr
# Panama
# es
# Georgia
# ab
# Bosnia and Herzegovina
# hr
# Eritrea
# en
# Uruguay
# es
# Mongolia
# mn
# Albania
# sq
# Armenia
# hy
# Jamaica
# en
# Lithuania
# lt
# Qatar
# ar
# Moldova
# ro
# Namibia
# en
# Botswana
# en
# Lesotho
# en
# The Gambia
# en
# North Macedonia
# sq
# Slovenia
# sl
# Gabon
# fr
# Latvia
# lv
# Guinea-Bissau
# pt
# Bahrain
# ar
# Trinidad and Tobago
# en
# Eswatini
# en
# Estonia
# et
# East Timor
# pt
# Equatorial Guinea
# fr
# Mauritius
# fr
# Cyprus
# tr
# Djibouti
# ar
# Fiji
# en
# Comoros
# fr
# Bhutan
# dz
# Guyana
# en
# Luxembourg
# fr
# Montenegro
# cnr
# Solomon Islands
# en
# Suriname
# nl
# Cape Verde
# pt
# Malta
# en
# Maldives
# dv
# Brunei
# en
# The Bahamas
# en
# Belize
# en
# Iceland
# is
# Barbados
# en
# Vanuatu
# fr
# Orange Free State
# nl
# São Tomé and Príncipe
# pt
# Samoa
# en
# Saint Lucia
# en
# Kiribati
# en
# Saint Vincent and the Grenadines
# en
# Tonga
# en
# Grenada
# en
# Federated States of Micronesia
# en
# Antigua and Barbuda
# en
# Orange Free State
# nl
# Seychelles
# fr
# Andorra
# ca
# Dominica
# en
# Saint Kitts and Nevis
# en
# Marshall Islands
# en
# Monaco
# fr
# Liechtenstein
# de
# San Marino
# it
# Palau
# en
# Nauru
# en
# Tuvalu
# en
# Vatican City
# fr

# %% [markdown]
# Last names in english

# %%
query = '''
SELECT ?name ?nameLabel ?count
WITH {
  SELECT ?name ?nameLabel (count(?person) AS ?count) WHERE {
    # ?person wdt:P734 ?name .  
    # ?person wdt:P27 %s . 
  }
  GROUP BY ?name ?nameLabel
  ORDER BY DESC(?count)
  LIMIT 100
} AS %%results
WHERE {
  INCLUDE %%results
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
ORDER BY DESC(?count)
'''
last_by_country_e = collections.defaultdict(lambda: collections.defaultdict(lambda: 0))
for country in countries:
    print(country.label.en)
    last = query % ('wd:%s' % country.code)
    results = wiki.query(last)
    for x in results["results"]["bindings"]:
#         print(x)
        last_by_country_e[country.label.en.replace(' ', '_')][x['nameLabel']['value']] += int(x['count']['value'])
# Out:
# China
# India
# United States
# Indonesia
# Brazil
# Pakistan
# Nigeria
# Bangladesh
# Russia
# Mexico
# Japan
# Ethiopia
# Philippines
# Egypt
# Vietnam
# Congo
# Germany
# Turkey
# Iran
# France
# United Kingdom
# Thailand
# Italy
# South Africa
# Tanzania
# Myanmar
# South Korea
# Colombia
# Kenya
# Spain
# Argentina
# Uganda
# Ukraine
# Algeria
# Sudan
# Poland
# Iraq
# Canada
# Morocco
# Afghanistan
# Saudi Arabia
# Uzbekistan
# Malaysia
# Angola
# Mozambique
# Nepal
# Peru
# Venezuela
# Yemen
# Ghana
# Madagascar
# North Korea
# Australia
# Ivory Coast
# Cameroon
# Niger
# Sri Lanka
# Romania
# Burkina Faso
# Malawi
# Mali
# Kazakhstan
# Syria
# Chile
# Guatemala
# the Netherlands
# Zambia
# Ecuador
# Zimbabwe
# Cambodia
# Senegal
# Chad
# Guinea
# South Sudan
# Rwanda
# Tunisia
# Cuba
# Belgium
# Benin
# Bolivia
# Somalia
# Haiti
# Burundi
# Greece
# Czech Republic
# Portugal
# Jordan
# Dominican Republic
# Sweden
# Azerbaijan
# Hungary
# Belarus
# United Arab Emirates
# Honduras
# Israel
# Tajikistan
# Austria
# Switzerland
# Papua New Guinea
# Togo
# Sierra Leone
# Serbia
# Bulgaria
# Laos
# Paraguay
# Libya
# El Salvador
# Nicaragua
# Kyrgyzstan
# Lebanon
# Singapore
# Turkmenistan
# Denmark
# Denmark
# Finland
# Slovakia
# Norway
# Congo
# New Zealand
# Costa Rica
# Oman
# Ireland
# Liberia
# Central African Republic
# Kuwait
# Mauritania
# Croatia
# Panama
# Georgia
# Bosnia and Herzegovina
# Eritrea
# Uruguay
# Mongolia
# Albania
# Armenia
# Jamaica
# Lithuania
# Qatar
# Moldova
# Namibia
# Botswana
# Lesotho
# The Gambia
# North Macedonia
# Slovenia
# Gabon
# Latvia
# Guinea-Bissau
# Bahrain
# Trinidad and Tobago
# Eswatini
# Estonia
# East Timor
# Equatorial Guinea
# Mauritius
# Cyprus
# Djibouti
# Fiji
# Comoros
# Bhutan
# Guyana
# Luxembourg
# Montenegro
# Solomon Islands
# Suriname
# Cape Verde
# Malta
# Maldives
# Brunei
# The Bahamas
# Belize
# Iceland
# Barbados
# Vanuatu
# Orange Free State
# São Tomé and Príncipe
# Samoa
# Saint Lucia
# Kiribati
# Saint Vincent and the Grenadines
# Tonga
# Grenada
# Federated States of Micronesia
# Antigua and Barbuda
# Orange Free State
# Seychelles
# Andorra
# Dominica
# Saint Kitts and Nevis
# Marshall Islands
# Monaco
# Liechtenstein
# San Marino
# Palau
# Nauru
# Tuvalu
# Vatican City

# %%
mnames = extract_roberta(male_names);
fnames = extract_roberta(female_names);
lnames = extract_roberta(last_names)

# %%
# male_by_country['Brazil']

# %%
def valid_name(name):
    if ('.' in name and len(name)<3) or any([x.isdigit() for x in name]):
        print('F: %s' % name)
        return False
    return True

# %%
for country in male_by_country:
    male_by_country[country] =  [a[0] for a in sorted(male_by_country[country].items(), key=lambda x:-x[1]) if valid_name(a[0])][:100]
for country in female_by_country:
    female_by_country[country] =  [a[0] for a in sorted(female_by_country[country].items(), key=lambda x:-x[1]) if valid_name(a[0])][:100]
for country in last_by_country:
    last_by_country[country] =  [a[0] for a in sorted(last_by_country[country].items(), key=lambda x:-x[1]) if valid_name(a[0])][:100]
# Out:
# F: K.
# F: P.
# F: S.
# F: M.
# F: A.
# F: R.
# F: V.
# F: T.
# F: N.
# F: C.
# F: B.
# F: G.
# F: D.
# F: J.
# F: H.
# F: E.
# F: O.
# F: L.
# F: U.
# F: Y.
# F: J.
# F: A.
# F: M.
# F: A.
# F: M.
# F: Q28790124
# F: A.
# F: S.
# F: B.
# F: C.
# F: A.
# F: Q66937416
# F: K.
# F: Q76885428
# F: Q66936752
# F: Q66937269
# F: Q57079574
# F: R.
# F: S.
# F: Q89128080
# F: A.
# F: M.
# F: Q60691248
# F: H.
# F: Q16628866
# F: K.
# F: S.
# F: M.
# F: V.
# F: G.
# F: P.
# F: T.
# F: A.
# F: D.
# F: B.
# F: C.
# F: E.
# F: S.
# F: M.
# F: K.
# F: A.
# F: P.
# F: C.
# F: T.
# F: D.
# F: H.
# F: V.
# F: R.
# F: J.
# F: G.
# F: W.
# F: N.
# F: E.
# F: B.
# F: U.
# F: Y.
# F: L.
# F: I.
# F: J.
# F: Q65298329
# F: Н.
# F: S.
# F: B.
# F: S.
# F: V.
# F: K.
# F: Q4247853
# F: S.
# F: E.
# F: A.
# F: Z.
# F: K.
# F: A.
# F: Q45763546
# F: Q65767684
# F: Y.
# F: E.
# F: S.
# F: J.
# F: C.
# F: R.
# F: A.
# F: E.
# F: Q64785309
# F: Q64785142
# F: A.
# F: S.
# F: C.
# F: B.
# F: D.
# F: M.
# F: S.
# F: P.
# F: B.
# F: K.
# F: R.
# F: T.
# F: V.
# F: A.
# F: C.
# F: N.
# F: Q25863245
# F: Q74550176
# F: Q69838313
# F: N.
# F: Q63115200
# F: S.
# F: Q45321546
# F: Q94579019
# F: Q66361368
# F: Q56425071
# F: F.
# F: Q58009691
# F: Q70611432
# F: Q50940212
# F: Q74421605
# F: Q55979066
# F: Q65767947
# F: Q55312707
# F: Q63144043
# F: Q67198984
# F: Q42327883
# F: Q97120444
# F: Q51159804
# F: Q47092720
# F: Q67194982
# F: Q56254960
# F: Q96105109
# F: Q59352708
# F: Q74421605
# F: Q80566758
# F: Q60239827
# F: Q65553777
# F: Q45096319
# F: Q94579019
# F: K.
# F: A.
# F: Q51272256
# F: Q88229179
# F: J.
# F: Q56692268
# F: Q62972673
# F: Q55979066
# F: Q52328234
# F: Q51545569
# F: Q64692658
# F: Q55526953
# F: Q50946340
# F: Q65767828
# F: Q63725968
# F: Q55314355
# F: B.
# F: G.
# F: Q45321546
# F: M.
# F: Q30246534
# F: A.
# F: Q69886076
# F: Q65189565
# F: Q79465858
# F: Q28914650
# F: Q51545569
# F: I.
# F: Q86685520
# F: Q94368759
# F: Z.
# F: Q97671765
# F: Q52358987
# F: Q48800342
# F: Q28871190
# F: Q43256664
# F: M.
# F: Q65189565
# F: Q97671765
# F: Q64657910
# F: Q19515301
# F: Q30080971
# F: C.
# F: R.
# F: Q65532156
# F: Q60239827
# F: Q67190715
# F: Q55400679
# F: Q52938034
# F: Q47454623
# F: Q57079566
# F: Q60023152
# F: Q95950131
# F: Q63928407
# F: Q63136026
# F: Q97036146
# F: Q56462637
# F: Q56244878
# F: Q18921304
# F: Q21125525
# F: Q24955672
# F: Q21125825
# F: Q47454428
# F: Q21126461
# F: Q21126527
# F: Q24953884
# F: Q28947845
# F: Q24955550
# F: Q18437444
# F: Q47454473
# F: Q16072112
# F: Q21180656
# F: Q21993849
# F: Q64829493
# F: Q84265651
# F: Q65562292
# F: Q37259498
# F: Q21125617
# F: Q24957485
# F: Q21126235
# F: Q24958361
# F: t1816212262
# F: Q47454474
# F: Q21125738
# F: Q47454323
# F: Q47454500
# F: Q47454379
# F: Q24954346
# F: Q24953148
# F: Q21125875
# F: Q24958232
# F: Q24953071
# F: Q16286891
# F: t1038705078
# F: t2001604864
# F: t1661779107
# F: Q24957913
# F: Q56810095
# F: Q12862919
# F: Q56798209
# F: Q24955237
# F: Q24958339
# F: Q24954083
# F: Q47454288
# F: Q72739323
# F: Q60228150
# F: Q24958283
# F: Q21125589
# F: Q63028885
# F: Q56451835
# F: Q24957840
# F: Q47454677
# F: Q64764873
# F: Q47454677
# F: Q60791688
# F: Q60793620
# F: Q21126712
# F: Q47454442
# F: Q24957458
# F: Q83791678
# F: Q57955377
# F: Q38370520
# F: Q15850851
# F: Q56119214
# F: Q47454719
# F: Q64759752

# %%
for country in male_by_country_e:
    male_by_country_e[country] =  [a[0] for a in sorted(male_by_country_e[country].items(), key=lambda x:-x[1]) if valid_name(a[0])][:100]
for country in female_by_country_e:
    female_by_country_e[country] =  [a[0] for a in sorted(female_by_country_e[country].items(), key=lambda x:-x[1]) if valid_name(a[0])][:100]
for country in last_by_country_e:
    last_by_country_e[country] =  [a[0] for a in sorted(last_by_country_e[country].items(), key=lambda x:-x[1]) if valid_name(a[0])][:100]
# Out:
# F: K.
# F: S.
# F: M.
# F: P.
# F: A.
# F: R.
# F: V.
# F: T.
# F: C.
# F: N.
# F: B.
# F: G.
# F: D.
# F: J.
# F: H.
# F: E.
# F: O.
# F: L.
# F: U.
# F: Y.
# F: J.
# F: A.
# F: M.
# F: A.
# F: M.
# F: Q28790124
# F: A.
# F: M.
# F: S.
# F: B.
# F: K.
# F: J.
# F: Q105688322
# F: Q66936752
# F: Q66937269
# F: Q104597043
# F: R.
# F: Q89128080
# F: S.
# F: A.
# F: Q60691248
# F: Q22977313
# F: Q28790124
# F: Q22977313
# F: H.
# F: Q22977313
# F: Q16628866
# F: K.
# F: S.
# F: M.
# F: V.
# F: G.
# F: P.
# F: T.
# F: A.
# F: D.
# F: B.
# F: C.
# F: Q22977313
# F: Q28790124
# F: H.
# F: E.
# F: Q69508563
# F: Q69509056
# F: Q69513144
# F: Q69507241
# F: Q69507811
# F: Q69509665
# F: Q69507851
# F: Q69509707
# F: Q69508592
# F: Q69512349
# F: Q69511774
# F: Q69512359
# F: Q69513494
# F: Q69510784
# F: Q69511120
# F: Q69508466
# F: Q69509301
# F: Q69512835
# F: Q69511013
# F: Q69509840
# F: Q69510545
# F: Q91247505
# F: Q65178181
# F: S.
# F: M.
# F: K.
# F: A.
# F: P.
# F: C.
# F: T.
# F: D.
# F: H.
# F: V.
# F: R.
# F: J.
# F: G.
# F: W.
# F: N.
# F: E.
# F: B.
# F: U.
# F: Y.
# F: L.
# F: I.
# F: Q65557977
# F: Q65557984
# F: Q22977313
# F: Q98663505
# F: Q55098138
# F: Q98276047
# F: Q101985549
# F: J.
# F: Q106182761
# F: Q105299694
# F: Q22977313
# F: Q51751692
# F: Q98554608
# F: Q42313676
# F: Q63931228
# F: Q30336832
# F: Q4247853
# F: Q65298329
# F: Q21127768
# F: N.
# F: Q105073737
# F: S.
# F: B.
# F: Q12283831
# F: Q62714910
# F: Q22977313
# F: Q63939154
# F: Q56370603
# F: Q98667567
# F: Q4058785
# F: S.
# F: V.
# F: K.
# F: Q4247853
# F: Q22977313
# F: D.
# F: Q22977313
# F: Q55435721
# F: Q63934955
# F: Q20390755
# F: Q64786503
# F: Q65178171
# F: E.
# F: Q23688631
# F: Q43261855
# F: M.
# F: A.
# F: Z.
# F: K.
# F: A.
# F: Q45763546
# F: Q105001291
# F: Q63930237
# F: Q65767684
# F: Q98555101
# F: I.
# F: S.
# F: Q65767720
# F: J.
# F: C.
# F: R.
# F: A.
# F: E.
# F: Q64785309
# F: Q64785142
# F: A.
# F: S.
# F: C.
# F: B.
# F: D.
# F: Q98102383
# F: Q98102552
# F: Q98102441
# F: Q98102368
# F: Q98102377
# F: M.
# F: S.
# F: R.
# F: B.
# F: P.
# F: K.
# F: T.
# F: V.
# F: A.
# F: C.
# F: N.
# F: Q56605569
# F: Q25863245
# F: Q74550176
# F: Q69838313
# F: Q102469230
# F: N.
# F: Q63115200
# F: S.
# F: Q45321546
# F: Q98553609
# F: Q94579019
# F: Q66984277
# F: Q66737380
# F: Q66361368
# F: Q58009691
# F: Q98554868
# F: Q70611432
# F: Q47344402
# F: Q50940212
# F: Q65767947
# F: Q74421605
# F: Q55312707
# F: Q63144043
# F: Q65681582
# F: Q42327883
# F: Q67198984
# F: Q52387504
# F: Q47092720
# F: Q54869491
# F: Q64958458
# F: Q20413251
# F: Q56669296
# F: Q60691507
# F: Q67194982
# F: Q52384091
# F: Q55401325
# F: Q86833690
# F: Q54371387
# F: Q67194982
# F: Q56254960
# F: Q96105109
# F: Q74421605
# F: Q80566758
# F: Q104788112
# F: Q60239827
# F: Q65553777
# F: Q45096319
# F: Q94579019
# F: Q97463049
# F: Q69514579
# F: Q69507261
# F: Q69511834
# F: Q69507639
# F: Q69507778
# F: Q69514898
# F: Q66736259
# F: Q65667180
# F: Q66348562
# F: Q25906883
# F: Q66369814
# F: K.
# F: A.
# F: Q87470008
# F: Q66736761
# F: Q66574725
# F: Q65667180
# F: Q66736761
# F: Q66348562
# F: Q66574725
# F: Q66736472
# F: Q65667180
# F: Q66736259
# F: Q50396612
# F: Q51272256
# F: Q88229179
# F: J.
# F: Q55059810
# F: Q65767638
# F: Q86831053
# F: Q86831718
# F: Q96482668
# F: Q86075889
# F: Q50807475
# F: Q65767626
# F: Q106091886
# F: Q103998410
# F: Q98602766
# F: Q89200191
# F: Q87399478
# F: Q101583538
# F: Q105756209
# F: Q62972673
# F: Q98931309
# F: Q51545569
# F: Q52328234
# F: Q64692658
# F: Q63488863
# F: Q3147560
# F: Q50946340
# F: Q55526953
# F: Q55314355
# F: Q67195346
# F: Q100556142
# F: Q56827437
# F: Q98555012
# F: Q61729400
# F: Q12205910
# F: Q45321546
# F: Q56250145
# F: Q65767947
# F: Q99235518
# F: Q25543604
# F: Q99471699
# F: Q104601704
# F: Q40379774
# F: Q55791431
# F: Q53673524
# F: A.
# F: Q69886076
# F: Q65189565
# F: Q51545569
# F: I.
# F: Q86685520
# F: Q94368759
# F: Z.
# F: Q52358987
# F: Q56087099
# F: Q95599643
# F: Q66361292
# F: Q98555012
# F: Q31271014
# F: Q88312661
# F: Q16382264
# F: Q20508296
# F: Q28871190
# F: Q43256664
# F: M.
# F: Q65189565
# F: Q64657910
# F: Q65767659
# F: Q65767249
# F: Q98555156
# F: C.
# F: Q64578254
# F: R.
# F: Q65532156
# F: Q60239827
# F: Q67190715
# F: Q98554530
# F: G.
# F: Q49224645
# F: Q59640401
# F: Q100230960
# F: Q52938034
# F: Q84265320
# F: Q98515275
# F: Q98410483
# F: Q77173048
# F: Q47454623
# F: Q104377210
# F: Q88963647
# F: Q104619455
# F: Q105450848
# F: Q66057639
# F: Q53213358
# F: Q61905318
# F: Q95950131
# F: Q56669305
# F: Q99892211
# F: Q53728864
# F: Q56753448
# F: Q56152691
# F: Q55862776
# F: Q64786510
# F: Q61590692
# F: Q12188376
# F: Q59296598
# F: Q57516865
# F: Q57419065
# F: Q56784375
# F: Q30083005
# F: Q22684026
# F: Q56676471
# F: Q105968711
# F: Q63136026
# F: Q56462637
# F: Q97036146
# F: Q56244878
# F: Q56753720
# F: Q56160711
# F: Q56024409
# F: Q55956644
# F: t2226681333
# F: Q104813187
# F: Q51879357
# F: Q50413981
# F: Q55010570
# F: Q53254072
# F: Q59247519
# F: Q76964260
# F: Q22932682
# F: Q61890571
# F: Q24955672
# F: Q21125525
# F: Q21126527
# F: Q24953884
# F: Q18437444
# F: Q21125825
# F: Q47454428
# F: Q37081183
# F: Q21126461
# F: Q28947845
# F: Q24955550
# F: Q22685889
# F: Q66057678
# F: Q60617430
# F: Q52155974
# F: Q60617256
# F: Q55010570
# F: Q55110361
# F: Q47454473
# F: Q63759636
# F: Q104018155
# F: Q91107257
# F: Q102189966
# F: Q100266697
# F: Q98211156
# F: Q86601838
# F: Q99317364
# F: Q63140598
# F: Q18235297
# F: Q24957125
# F: Q24957973
# F: Q25380336
# F: Q21125791
# F: Q24958353
# F: Q21125863
# F: Q18510535
# F: Q24958161
# F: Q24958147
# F: Q104891201
# F: Q104892979
# F: Q68707752
# F: Q105084721
# F: Q105818924
# F: Q64494898
# F: Q55110361
# F: Q55725962
# F: Q21180656
# F: Q104522510
# F: Q102360765
# F: Q98412001
# F: Q99747575
# F: Q106202907
# F: Q99236010
# F: Q99317364
# F: Q97154074
# F: Q76542820
# F: Q99746669
# F: Q99315376
# F: Q104215000
# F: Q21993849
# F: Q64027164
# F: Q53213358
# F: Q63267209
# F: Q92742164
# F: Q65562292
# F: Q16328708
# F: Q29652532
# F: Q55841576
# F: Q60691521
# F: Q60040680
# F: Q56426642
# F: Q55679514
# F: Q56071803
# F: Q55497997
# F: Q58335424
# F: Q105081198
# F: Q50803421
# F: Q63383927
# F: Q60040868
# F: Q50741045
# F: Q55422098
# F: Q12222409
# F: Q21125617
# F: Q24957485
# F: Q19886251
# F: Q55198620
# F: Q37081183
# F: Q24958361
# F: Q87262579
# F: Q20519947
# F: Q4405005
# F: Q55340950
# F: Q55680730
# F: Q62396161
# F: Q100384330
# F: Q55791529
# F: Q66663727
# F: Q21126126
# F: Q4308531
# F: Q37081183
# F: Q60823811
# F: Q21126610
# F: Q47454510
# F: Q4405814
# F: Q4387199
# F: Q5159681
# F: Q47454474
# F: Q62714980
# F: Q37081183
# F: Q21125772
# F: Q60824704
# F: Q16708247
# F: Q47454418
# F: Q24954211
# F: Q47454473
# F: Q24955385
# F: Q21125514
# F: Q47454354
# F: Q24954346
# F: Q24958181
# F: Q4179266
# F: Q18235297
# F: Q21175659
# F: Q24953886
# F: Q4242254
# F: Q4081415
# F: Q55877247
# F: Q59329660
# F: Q21125738
# F: Q47454323
# F: Q24953071
# F: Q47454500
# F: Q24954346
# F: Q24953148
# F: Q21125875
# F: Q24958232
# F: t2103674763
# F: Q92053180
# F: Q98688514
# F: t2200994068
# F: Q88459454
# F: Q96358868
# F: Q97733633
# F: Q96250742
# F: Q55380065
# F: t1661779107
# F: Q56786327
# F: Q61028773
# F: Q55435741
# F: Q52826662
# F: Q51210749
# F: Q101295449
# F: Q56810095
# F: Q12862919
# F: Q100268852
# F: Q4058742
# F: Q24958339
# F: Q24955237
# F: Q24954083
# F: Q60329571
# F: Q105534075
# F: Q25390421
# F: Q60228150
# F: Q24958283
# F: Q21125589
# F: Q56451835
# F: Q24957840
# F: Q4419220
# F: Q47454677
# F: Q64605806
# F: Q61744472
# F: Q64764873
# F: Q47454677
# F: Q65109450
# F: Q65963691
# F: Q60793620
# F: Q63568661
# F: Q47454442
# F: Q24957458
# F: Q104376970
# F: Q102442877
# F: Q86220866
# F: Q83791678
# F: Q57955377
# F: Q38370520
# F: Q56119214
# F: Q47454719
# F: Q63759928

# %%
for lang in mnames:
    mnames[lang] =  [a[0] for a in sorted(mnames[lang].items(), key=lambda x:-x[1]) if valid_name(a[0])][:100]
for lang in fnames:
    fnames[lang] =  [a[0] for a in sorted(fnames[lang].items(), key=lambda x:-x[1]) if valid_name(a[0])][:100]
for lang in lnames:
    lnames[lang] =  [a[0] for a in sorted(lnames[lang].items(), key=lambda x:-x[1]) if valid_name(a[0])][:100]
# Out:
# F: J.
# F: Y.
# F: E.
# F: D.
# F: J.
# F: S.
# F: A.
# F: E.
# F: V.
# F: K.
# F: B.
# F: C.
# F: Q60691248
# F: Z.
# F: Q65767684
# F: A.
# F: S.
# F: B.
# F: C.
# F: M.
# F: R.
# F: K.
# F: P.
# F: S.
# F: M.
# F: A.
# F: R.
# F: V.
# F: T.
# F: N.
# F: C.
# F: B.
# F: G.
# F: D.
# F: J.
# F: H.
# F: E.
# F: O.
# F: L.
# F: U.
# F: Y.
# F: A.
# F: M.
# F: Q45763546
# F: K.
# F: S.
# F: M.
# F: V.
# F: G.
# F: P.
# F: T.
# F: A.
# F: D.
# F: B.
# F: C.
# F: S.
# F: E.
# F: Q64785309
# F: Q64785142
# F: Q65298329
# F: Н.
# F: S.
# F: M.
# F: K.
# F: A.
# F: P.
# F: C.
# F: T.
# F: D.
# F: H.
# F: V.
# F: R.
# F: J.
# F: G.
# F: W.
# F: N.
# F: E.
# F: B.
# F: U.
# F: Y.
# F: L.
# F: I.
# F: Q57079574
# F: R.
# F: S.
# F: Q89128080
# F: A.
# F: M.
# F: Q28790124
# F: H.
# F: Q16628866
# F: A.
# F: Q66937416
# F: K.
# F: Q76885428
# F: Q66936752
# F: Q66937269
# F: Q94579019
# F: Q47092720
# F: Q51272256
# F: Q88229179
# F: J.
# F: Q69886076
# F: Q94368759
# F: Z.
# F: M.
# F: Q64657910
# F: C.
# F: Q65189565
# F: Q48800342
# F: Q74550176
# F: Q69838313
# F: N.
# F: Q63115200
# F: S.
# F: Q55979066
# F: Q62972673
# F: Q50940212
# F: Q74421605
# F: Q51545569
# F: Q45321546
# F: Q52328234
# F: Q64692658
# F: Q65767947
# F: Q55312707
# F: Q55526953
# F: Q50946340
# F: Q63144043
# F: Q67198984
# F: Q42327883
# F: Q56254960
# F: Q96105109
# F: Q65767828
# F: Q63725968
# F: Q55314355
# F: Q97120444
# F: Q51159804
# F: Q67194982
# F: Q59352708
# F: Q28871190
# F: Q30246534
# F: Q25863245
# F: Q79465858
# F: Q28914650
# F: R.
# F: M.
# F: S.
# F: P.
# F: B.
# F: K.
# F: R.
# F: T.
# F: V.
# F: A.
# F: C.
# F: N.
# F: Q56692268
# F: Q97671765
# F: Q66361368
# F: Q56425071
# F: F.
# F: Q58009691
# F: Q60239827
# F: Q65553777
# F: Q45096319
# F: Q94579019
# F: Q65532156
# F: Q67190715
# F: Q43256664
# F: Q86685520
# F: Q65189565
# F: M.
# F: B.
# F: G.
# F: A.
# F: I.
# F: Q52358987
# F: K.
# F: A.
# F: Q70611432
# F: Q19515301
# F: Q30080971
# F: Q80566758
# F: Q21993849
# F: Q55400679
# F: Q47454473
# F: Q95950131
# F: Q21180656
# F: t2001604864
# F: Q60228150
# F: Q57955377
# F: Q47454719
# F: Q24958283
# F: Q21125589
# F: Q63028885
# F: Q56451835
# F: Q24957840
# F: Q64829493
# F: Q84265651
# F: Q60023152
# F: Q63928407
# F: Q63136026
# F: Q18921304
# F: Q16072112
# F: t1661779107
# F: Q64764873
# F: Q24955237
# F: Q24958339
# F: Q24954083
# F: Q37259498
# F: Q21125617
# F: Q24957485
# F: Q21126235
# F: Q24958361
# F: Q56798209
# F: t1038705078
# F: Q38370520
# F: Q15850851
# F: Q64759752
# F: Q47454677
# F: Q83791678
# F: Q56119214
# F: Q47454288
# F: Q72739323
# F: Q65562292
# F: Q47454474
# F: t1816212262
# F: Q47454623
# F: Q57079566
# F: Q60791688
# F: Q60793620
# F: Q21125525
# F: Q24955672
# F: Q97036146
# F: Q56462637
# F: Q56244878
# F: Q21125825
# F: Q47454428
# F: Q21126461
# F: Q21126527
# F: Q24953884
# F: Q28947845
# F: Q24955550
# F: Q18437444
# F: Q52938034

# %%
male_by_country = munch.Munch(dict(male_by_country))
female_by_country = munch.Munch(dict(female_by_country))
last_by_country = munch.Munch(dict(last_by_country))

# %%
male_by_country_e = munch.Munch(dict(male_by_country_e))
female_by_country_e = munch.Munch(dict(female_by_country_e))
last_by_country_e = munch.Munch(dict(last_by_country_e))

# %%
data = munch.Munch({'countries': countries,
                   'mnames': mnames,
                   'fnames': fnames,
                    'lnames': lnames,
                   'male_by_country': male_by_country,
                   'last_by_country': last_by_country,
                   'female_by_country': female_by_country
                   'male_by_country_english': male_by_country_e,
                   'last_by_country_english': last_by_country_e,
                   'female_by_country_english': female_by_country_e
                   })

# %%
import pickle
pickle.dump(data, open('/home/marcotcr/tmp/country_stuff.pkl', 'wb'))
pickle.dump(wiki, open('/home/marcotcr/tmp/wikidata_queries.pkl', 'wb'))

# %%
data = pickle.load(open('/home/marcotcr/tmp/country_stuff.pkl', 'rb'))
wiki = pickle.load(open('/home/marcotcr/tmp/wikidata_queries.pkl', 'rb'))

# %%
data.countries[4]
# Out:
# Munch({'code': 'Q155', 'label': Munch({'en': 'Brazil', 'fr': 'Brésil', 'de': 'Brasilien', 'af': 'Brasilië', 'sq': 'Brazili', 'am': 'ብራዚል', 'ar': 'البرازيل', 'hy': 'Բրազիլիա', 'az': 'Braziliya', 'eu': 'Brasil', 'be': 'Бразілія', 'bn': 'ব্রাজিল', 'bs': 'Brazil', 'br': 'Brazil', 'bg': 'Бразилия', 'my': 'ဘရာဇီးနိုင်ငံ', 'ca': 'Brasil', 'zh': '巴西', 'hr': 'Brazil', 'cs': 'Brazílie', 'da': 'Brasilien', 'nl': 'Brazilië', 'eo': 'Brazilo', 'et': 'Brasiilia', 'fi': 'Brasilia', 'gl': 'Brasil', 'ka': 'ბრაზილია', 'el': 'Βραζιλία', 'gu': 'બ્રાઝિલ', 'ha': 'Brazil', 'he': 'ברזיל', 'hi': 'ब्राज़ील', 'hu': 'Brazília', 'is': 'Brasilía', 'id': 'Brasil', 'ga': 'An Bhrasaíl', 'it': 'Brasile', 'ja': 'ブラジル', 'jv': 'Brasil', 'kn': 'ಬ್ರೆಜಿಲ್', 'kk': 'Бразилия', 'km': 'ប្រេស៊ីល', 'ko': '브라질', 'ku': 'Brazîl', 'ky': 'Бразилия', 'lo': 'ປະເທດບະເລຊິນ', 'la': 'Brasilia', 'lv': 'Brazīlija', 'lt': 'Brazilija', 'mk': 'Бразил', 'mg': 'Brazila', 'ms': 'Brazil', 'ml': 'ബ്രസീൽ', 'mr': 'ब्राझील', 'mn': 'Бразил', 'ne': 'ब्राजिल', 'no': 'Brasil', 'ps': 'برازیل', 'fa': 'برزیل', 'pl': 'Brazylia', 'pt': 'Brasil', 'pa': 'ਬ੍ਰਾਜ਼ੀਲ', 'ro': 'Brazilia', 'ru': 'Бразилия', 'gd': 'Braisil', 'sr': 'Бразил', 'sd': 'برازيل', 'si': 'බ්රසීලය', 'sk': 'Brazília', 'sl': 'Brazilija', 'so': 'Barasiil', 'es': 'Brasil', 'su': 'Brasil', 'sw': 'Brazil', 'sv': 'Brasilien', 'ta': 'பிரேசில்', 'te': 'బ్రెజిల్', 'th': 'ประเทศบราซิล', 'tr': 'Brezilya', 'uk': 'Бразилія', 'ur': 'برازیل', 'ug': 'برازىلىيە', 'uz': 'Braziliya', 'vi': 'Brasil', 'cy': 'Brasil', 'xh': 'Brasil', 'yi': 'בראזיל'}), 'lang_codes': 'pt', 'primary_lang': 'pt', 'population': '210147125', 'cities': [Munch({'code': 'Q174', 'label': Munch({'en': 'São Paulo', 'fr': 'São Paulo', 'de': 'São Paulo', 'af': 'São Paulo', 'sq': 'São Paulo', 'am': 'ሳው ፓውሉ', 'ar': 'ساو باولو', 'hy': 'Սան Պաուլո', 'az': 'San Paulo', 'eu': 'São Paulo', 'be': 'Сан-Паўлу', 'bn': 'সাও পাওলো', 'bs': 'São Paulo', 'br': 'São Paulo', 'bg': 'Сао Пауло', 'my': 'ဆောပိုလိုမြို့', 'ca': 'São Paulo', 'zh': '圣保罗', 'hr': 'São Paulo', 'cs': 'São Paulo', 'da': 'São Paulo', 'nl': 'São Paulo', 'eo': 'San-Paŭlo', 'et': 'São Paulo', 'fi': 'São Paulo', 'gl': 'São Paulo', 'ka': 'სან-პაულუ', 'el': 'Σάο Πάολο', 'gu': 'સાઉ પાઉલો', 'ha': 'São Paulo', 'he': 'סאו פאולו', 'hi': 'साओ पाउलो', 'hu': 'São Paulo', 'is': 'São Paulo', 'id': 'São Paulo', 'ga': 'São Paulo', 'it': 'San Paolo', 'ja': 'サンパウロ', 'jv': 'São Paulo', 'kn': 'ಸಾವೊ ಪಾಲೊ', 'kk': 'Сан-Паулу', 'ko': '상파울루', 'ku': 'São Paulo', 'la': 'Paulopolis', 'lv': 'Sanpaulu', 'lt': 'San Paulas', 'mk': 'Сао Паоло', 'mg': 'São Paulo', 'ms': 'São Paulo', 'ml': 'സാവോ പോളോ', 'mr': 'साओ पाउलो', 'mn': 'Сан-Паоло', 'ne': 'साओ पाउलो', 'no': 'São Paulo', 'ps': 'ساو پاولو', 'fa': 'سائوپائولو', 'pl': 'São Paulo', 'pt': 'São Paulo', 'pa': 'ਸਾਓ ਪਾਓਲੋ', 'ro': 'São Paulo', 'ru': 'Сан-Паулу', 'gd': 'São Paulo', 'sr': 'Сао Пауло', 'si': 'සාවෝ\xa0-\xa0පෝලෝ', 'sk': 'São Paulo', 'sl': 'São Paulo', 'so': 'São Paulo', 'es': 'São Paulo', 'sw': 'São Paulo', 'sv': 'São Paulo', 'ta': 'சாவோ பாவுலோ', 'te': 'సావో పాలో', 'th': 'เซาเปาลู', 'tr': 'São Paulo', 'uk': 'Сан-Паулу', 'ur': 'ساؤ پالو', 'ug': 'San Pawlo', 'uz': 'San Paulu', 'vi': 'São Paulo', 'cy': 'São Paulo', 'yi': 'סאו פאולא'}), 'population': '12106920'}), Munch({'code': 'Q8678', 'label': Munch({'en': 'Rio de Janeiro', 'fr': 'Rio de Janeiro', 'de': 'Rio de Janeiro', 'af': 'Rio de Janeiro', 'sq': 'Rio de Zhaneiro', 'am': 'ሪዮ ዴ ጃኔይሮ', 'ar': 'ريو دي جانيرو', 'hy': 'Ռիո դե Ժանեյրո', 'az': 'Rio-de-Janeyro', 'eu': 'Rio de Janeiro', 'be': 'Рыа-дэ-Жанэйра', 'bn': 'রিউ দি জানেইরু', 'bs': 'Rio de Janeiro', 'br': 'Rio de Janeiro', 'bg': 'Рио де Жанейро', 'my': 'ရီယို ဒီ ဂျီးနေးရိုးမြို့', 'ca': 'Rio de Janeiro', 'zh': '里约热内卢', 'hr': 'Rio de Janeiro', 'cs': 'Rio de Janeiro', 'da': 'Rio de Janeiro', 'nl': 'Rio de Janeiro', 'eo': 'Rio-de-Ĵanejro', 'et': 'Rio de Janeiro', 'fi': 'Rio de Janeiro', 'gl': 'Río de Xaneiro', 'ka': 'რიო-დე-ჟანეირო', 'el': 'Ρίο ντε Τζανέιρο', 'gu': 'રિયો ડિ જેનેરો', 'ha': 'Rio de Janeiro', 'he': "ריו דה ז ...
